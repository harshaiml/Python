# %% [markdown]
# # Chapter 5
# Loops
#
# ---

# %% [markdown]
# ## Loops in Python
# ---
# Loops are used to repeat instructions.
# - while Loops

# %%
# while True :
#     print("Hello")

# # We can write Hello Unlimeted times using while loop 
# We can run this code

# %%
# Print Hello five times

count = 1
while count <= 5 : 
    print("Hello")
    count += 1
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
