# %% [markdown]
# # Chaptar 3
# **List & Tuple**
#
# ---

# %% [markdown]
# ## List in Python
# ---
# - A built-in data type store set of values
# - It can store elements of differrent type (integer, float, string, etc.)

# %%
marks = [87, 64, 33, 95, 76]     # List of student marks
student = ["Karan", 85, "Delhi"] # Student details in a list

student[0] = "Harsh"             # Allowed in Python
len(student)                     # Length of the list
# Out:
# 3

# %%
marks = [87.4, 64.5, 33.2, 95.0, 76.8]  # List of student marks as float
print(marks)                            # Print the list
print(type(marks))                      # Type of first element in the list
print(marks[0])                         # First element of the list
print(marks[-1])                        # Last element of the list
print(marks[1:4])                       # Slicing the list
marks[2] = 34.5                         # Modifying an element in the list
print(marks)                            # Print the modified list
# Out:
# [87.4, 64.5, 33.2, 95.0, 76.8]
# <class 'list'>
# 87.4
# 76.8
# [64.5, 33.2, 95.0]
# [87.4, 64.5, 34.5, 95.0, 76.8]

# %%
student = ["Shivam", 92.4, 18, "Bangalore"]  # Student details in a list
print(student)                               # Print the student details
# Out:
# ['Shivam', 92.4, 18, 'Bangalore']

# %%
# string --> immutable
# list   --> mutable

# %%
student = ["Shivam", 92.4, 18, "Bangalore"]  # Student details in a list
print(student[0])                            # Accessing the name
student[0] = "Rahul"                         # Modifying the name
print(student)                               # Print the modified student details
# Out:
# Shivam
# ['Rahul', 92.4, 18, 'Bangalore']

# %% [markdown]
# ## List Slicing
# ---
# Similer to Strings Slicing
#
# - list_name[ starting_idx : ending_idx ]  #ending idx is not include
# - marks = [87, 64, 33, 95, 76]
# - marks[1 : 4] is [64, 33, 95]
# - marks[ : 4 ]is name as marks[0 : 4]
# - marks[ 1 : ] is same as marks[ 1 : len(marks) ]
# - marks[ -3 : -1 ] is [33, 95]

# %%
marks = [87, 64, 33, 95, 76] # List of student marks
print(marks[1:4])            # Slicing the list to get elements from index 1 to 3
print(marks[1:])             # Slicing the list to get elements from index 1 to end
print(marks[-3:-1])          # Slicing the list to get elements from index -3 to -2
# Out:
# [64, 33, 95]
# [64, 33, 95, 76]
# [33, 95]

# %% [markdown]
# ## List Methods
# ---
# - list = [2, 1, 3]
# - list.append(4)               #adds one element at the end [2, 1, 3, 4]
# - list.sort()                  #sorts in ascending order [1, 2, 3]
# - list.sort( reverse=True)     #sorts in descending order [3, 2, 1]
# - list.insert(idx, el)         #insert element at index

# %%
# list.append(value)      # Adds value to the end of the list
# This is mutable operation

marks = [87, 64, 33, 95, 76]  # List of student marks
marks.append(88)              # Append 88 to the list
print(marks)                  # Print the updated list
# Out:
# [87, 64, 33, 95, 76, 88]

# %%
# list.sort() Sorts the list in ascending order

marks = [87, 64, 33, 95, 76]  # List of student marks
marks.sort()                  # Sort the list
print(marks)                  # Print the sorted list
# Out:
# [33, 64, 76, 87, 95]

# %%
list = [87, 64, 33, 95, 76, 85]
print(list.sort())
print(list)
# Out:
# None
# [33, 64, 76, 85, 87, 95]
