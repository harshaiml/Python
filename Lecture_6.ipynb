# %% [markdown]
# # Chapter 6
# ---
# Functions & Recursion

# %% [markdown]
# ## Functions in Python
# ---
# Block of statements that perform a specific task.

# %%
# def func_name( param1, param2..):    # function Definition

#     #some work
#     return val

# func_name(arg1, arg2..) # function call

# %%
# def sun(a, b):
#     s = a + b
#     return s

# print(sum(2, 3))

# %%
a = 5
b = 10

sum = a + b
print(sum)
# Out:
# 15

# %%
# # Using function

# def calc_sum(a, b):
#     sum = a + b
#     print(sum)
# calc_sum(5, 10)

# calc_sum(2, 10) # more lines of code

# calc_sum(12, 18)

# %%
# Function definition

def calc_sum(a, b):        # Parameters
    return a + b
sum = calc_sum(154, 1585)  # Function call; arguments 
print(sum)                 # Print
# Out:
# 1739

# %%
def print_hello():
    print("Hello")

print_hello()
# Out:
# Hello

# %%
def print_hello():
    print("Hello")

output = print_hello()
print(output)
# Out:
# Hello
# None

# %%
# Average of 3 numbers

def calc_avg(a, b, c):
    sum = a + b + c
    avg = sum / 3
    #print(avg)
    return avg

calc_avg(40, 50, 60)
# Out:
# 50.0

# %% [markdown]
# ## Function in Python
# ---
# 1. **Buli-in Function**
# - print()
# - len()
# - type()
# - range()
# 2. **User defined Function**

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Hello world", "Harsh") #sep = " "
# Out:
# Hello world Harsh

# %%
print("Hello world")   #sep = " "
print("Harsh")         #end = "\n"
# Out:
# Hello world
# Harsh

# %%
print("Hello world", end=" ")   #sep = " "
print("Harsh")                  #end = "\n"
# Out:
# Hello world Harsh

# %%
print("Hello world", end="$")   #sep = " "
print("Harsh")                  #end = "\n"
# Out:
# Hello world$Harsh
