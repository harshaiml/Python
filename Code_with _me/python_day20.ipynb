# %% [markdown]
# ### Functions in Python

# %%
def hellogreet():
    user = input("Enter your name :")
    print("Hello", user)

# %%
hellogreet()
# Out:
# Hello Harsh

# %%
def sum(a, b): # Create function
    sum = (a + b) 
    print("Sum of 2 number is", sum)

sum(4, 6) # Call Function
# Out:
# Sum of 2 number is 10

# %%
def avrage():
    num1 = int(input("Enter your 1st number:"))
    num2 = int(input("Enter your 2nd number:"))
    num3 = int(input("Enter your 3rd number:"))
    num4 = int(input("Enter your 4th number:"))
    avrage = (num1+num2+num3+num4)/4
    print("You enter the numbers is",num1,num2,num3,num4)
    print("Avrage of 4 numbers is", avrage)

avrage()
# Out:
# You enter the numbers is 10 20 30 40
# Avrage of 4 numbers is 25.0

# %%
def calculateGmean(a, b):
    mean = (a*b)/(a+b)
    print(mean)
# a = 9
# b = 8
calculateGmean(9, 8)
# c = 8
# d = 7
# calculateGmean(c, d)
# Out:
# 4.235294117647059

# %%
def isGreater(a, b):
    if(a>b):
        print("First number is greater")
    else:
        print("Second number is greater or equal")
a = 9
b = 8
isGreater(a, b)
# Out:
# First number is greater

# %%
def isLesser(a, b):
    pass
