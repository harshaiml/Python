# %% [markdown]
# ## Sets in Python

# %%
s = {2, 4, 2, 6}
print(s)
# Out:
# {2, 4, 6}

# %%
info = {"Carla", 19, False, 5.9, 19}
print(info)
# Out:
# {False, 'Carla', 19, 5.9}

# %%
harry = set()
print(type(harry))
# Out:
# <class 'set'>

# %%
info = {"Carla", 19, False, 5.9, 19}
print(info)

for value in info:
    print(value)
# Out:
# {False, 'Carla', 19, 5.9}
# False
# Carla
# 19
# 5.9
