# %% [markdown]
# ## f-strings in Python

# %%
letter = "Hey my name is {} and I am from {}"
country = "India"
name = "Harsh"
print(letter.format(name, country))
# Out:
# Hey my name is Harsh and I am from India

# %%
print(f"Hey my name is {name} and I an from {country}")
# Out:
# Hey my name is Harsh and I an from India

# %%
price = 49.09999
txt = f"for only {price:.2f} dollars!" 
print(txt)
# Out:
# for only 49.10 dollars!

# %%
print(type(f"{2 * 30}"))
# Out:
# <class 'str'>
