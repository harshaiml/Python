# %% [markdown]
# ## Docstrings in Python

# %%
def square(n):
    '''Take in a number n, return the square of n'''
    print(n**2)
square(5)
# Out:
# 25

# %%
def square(n):
    '''Take in a number n, return the square of n'''
    print(n**2)
square(5)
print(square.__doc__)
# Out:
# 25
# Take in a number n, return the square of n
