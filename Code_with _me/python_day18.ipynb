# %% [markdown]
# ### While Loops in Python

# %%
i = 0
while(i<3):
    print(i)
    i = i + 1

print("Done with the loop")
# Out:
# 0
# 1
# 2
# Done with the loop

# %%
i = 0
while(i<=3):
    print(i)
    i = i + 1
print("Done with  the loop")
# Out:
# 0
# 1
# 2
# 3
# Done with  the loop

# %%
i = 0
while(i<3):
    print(i+1)
    i = i + 1
print("Done with  the loop")
# Out:
# 1
# 2
# 3
# Done with  the loop

# %%
i = int(input("Enter the number: "))
while(i<=38):
    i = int(input("Enter the number: "))
    print(i)
print("Done with the loop")
# Out:
# 25
# 62
# Done with the loop

# %%
count = 5
while (count > 0):
    print(count)
    count = count - 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
count = 5
while (count > 0):
    print(count)
    count = count - 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
count = 5
while (count > 0):
    print(count)
    count = count - 1
else:
    print("I am inside else")
# Out:
# 5
# 4
# 3
# 2
# 1
# I am inside else
