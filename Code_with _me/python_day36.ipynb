# %% [markdown]
# ## Excepton Handling in Python

# %%
a = input("Enter the number: ")
print(f"Multiplication table of {a} is: ")

for i in range(1, 11):
    print(f"{int(a)} x {i} = {int(a)*i}")
# Out:
# Multiplication table of 8 is:
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80

# %%
a = input("Enter the number: ")
print(f"Multiplication table of {a} is: ")

try:
    for i in range(1, 11):
      print(f"{int(a)} x {i} = {int(a)*i}")
except:
    print("Invalid Input")

print("Some importent line of code")
print("End of program")
# Out:
# Multiplication table of 2 is:
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
# Some importent line of code
# End of program

# %%
try:
    num = int(input("Enter an integer: "))
    a = [6, 3]
    print(a[num])
except ValueError:
    print("Number entered is not an integer.")

except IndexError:
    print("Index Error")
# Out:
# Index Error
