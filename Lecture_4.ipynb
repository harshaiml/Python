# %% [markdown]
# # Chapter 4
# Dictionary & Set
#
# ---

# %% [markdown]
# ## Dictionary in Python
# ---
# - Dictionaries are used to store data value in **key:value** pairs
# - They are unordered, mutable(changeable) & don't allow duplicate keys
# - dict["name"],dict["cgpa"], dict["marks"]
# - dict["key"] = "value" #to assign or add new

# %%
# Creating dictionary

info = {                         # Dictionary starts here
    "key" : "value",             # key-value pair
    "name" : "Alice",            # Another key-value pair
    "learning" : "Python",       # Another key-value pair
    "age" : 25,                  # Integer value
    "is_adult" : True,           # Boolean value
    "marks" :85.5                # Float value
}                                # Dictionary ends here

print(info)                      # Print the entire dictionary
# Out:
# {'key': 'value', 'name': 'Alice', 'learning': 'Python', 'age': 25, 'is_adult': True, 'marks': 85.5}

# %%
info = {                                                  # Dictionary starts here
    "name" : "Alice",                                     # Another key-value pair
    "subject" : ["Python", "Java", "C++"],                # List as a value
    "topics" : ("OOP", "Data Structures", "Algorithms"),  # Tuple as a value
    "age" : 25,                                           # Integer value
    "is_adult" : True,                                    # Boolean value
    12.99 : 85.2                                          # Float as a key
}                                                         # Dictionary ends here

print(info)                                               # Print the entire dictionary
print(type(info))                                         # Print the type of 'info' to confirm it's a dictionary
# Out:
# {'name': 'Alice', 'subject': ['Python', 'Java', 'C++'], 'topics': ('OOP', 'Data Structures', 'Algorithms'), 'age': 25, 'is_adult': True, 12.99: 85.2}
# <class 'dict'>

# %%
info = {                                                  # Dictionary starts here
    "name" : "Alice",                                     # Another key-value pair
    "subject" : ["Python", "Java", "C++"],                # List as a value
    "topics" : ("OOP", "Data Structures", "Algorithms"),  # Tuple as a value
    "age" : 25,                                           # Integer value
    "is_adult" : True,                                    # Boolean value
    12.99 : 85.2                                          # Float as a key
}                                                         # Dictionary ends here

print(info["name"])                                       # Accessing value using key "name"
print(info["subject"])                                    # Accessing value using key "subject"
print(info["topics"])                                     # Accessing value using key "topics"
print(info["age"])                                        # Accessing value using key "age"
print(info["is_adult"])                                   # Accessing value using key "is_adult"
print(info[12.99])                                        # Accessing value using float key 12.99
# Out:
# Alice
# ['Python', 'Java', 'C++']
# ('OOP', 'Data Structures', 'Algorithms')
# 25
# True
# 85.2

# %%
info = {                                                  # Dictionary starts here
    "name" : "Alice",                                     # Another key-value pair
    "subject" : ["Python", "Java", "C++"],                # List as a value
    "topics" : ("OOP", "Data Structures", "Algorithms"),  # Tuple as a value
    "age" : 25,                                           # Integer value
    "is_adult" : True,                                    # Boolean value
    12.99 : 85.2                                          # Float as a key
}                                                         # Dictionary ends here

info["name"] = "Bob"                                      # Modifying value for key "name"
info["surname"] = "Smith"                                 # Adding new key-value pair
print(info)                                               # Print the entire dictionary
# Out:
# {'name': 'Bob', 'subject': ['Python', 'Java', 'C++'], 'topics': ('OOP', 'Data Structures', 'Algorithms'), 'age': 25, 'is_adult': True, 12.99: 85.2, 'surname': 'Smith'}

# %%
# null dictionary

info = {                                                  # Dictionary starts here
    "name" : "Alice",                                     # Another key-value pair
    "subject" : ["Python", "Java", "C++"],                # List as a value
    "topics" : ("OOP", "Data Structures", "Algorithms"),  # Tuple as a value
    "age" : 25,                                           # Integer value
    "is_adult" : True,                                    # Boolean value
    12.99 : 85.2                                          # Float as a key
}                                                         # Dictionary ends here

null_dict = {}                                            # Creating an empty dictionary
null_dict["name"] = "Alice"                             
print(null_dict)
# Out:
# {'name': 'Alice'}

# %% [markdown]
# ## Dictionary in Python
# ---
# **Nested** Dictionaries

# %%
# Nested Dictionaries

student = {
    "name" :"Shiv",
    "subjects" : {
        "phy" : 97,
        "chem" : 98,
        "math" : 95
    }
}

# This is Nested Dictionary

print(student)
print(student["subjects"])
print(student["subjects"]["chem"])
# Out:
# {'name': 'Shiv', 'subjects': {'phy': 97, 'chem': 98, 'math': 95}}
# {'phy': 97, 'chem': 98, 'math': 95}
# 98

# %% [markdown]
# ## Dictionary Method
# ---
# 1. myDict.keys() #return all keys
# 2. myDict.values() #return all values
# 3. myDict.items() #return all (key,value) pairs as tuples
# 4. myDict.get("key") #returns the key according to value
# 5. myDict.update(newDict) #insert the specified items to the dictionary

# %%
# myDict.keys()

student = {
    "name" :"Shiv",
    "subjects" : {
        "phy" : 97,
        "chem" : 98,
        "math" : 95
    }
}

print(student.keys())
# Out:
# dict_keys(['name', 'subjects'])

# %%
# This is my Dictiona

student = {
    "name" :"Shiv",
    "subjects" : {
        "phy" : 97,
        "chem" : 98,
        "math" : 95
    }
}

print(student.keys())
# Out:
# dict_keys(['name', 'subjects'])

# %%
# Type casting

student = {
    "name" :"Shiv",
    "subjects" : {
        "phy" : 97,
        "chem" : 98,
        "math" : 95
    }
}

print(len(student))
print(list(student.keys()))
print(len(list(student.keys())))
# Out:
# 2
# ['name', 'subjects']
# 2
